# %% [markdown]
# # Bayesian Uncertainty Minimization
#
# This demo shows how to minimize the uncertainty of a simple 1D function using Bayesian optimization with a GPR as the surrogate model. The GPR can use derivative information to aid in the regression.

# %%
import sys 
import numpy as np
import matplotlib.pyplot as plt
import time
import copy

sys.path.append("../..")
import gpder 
from gpder import UncertaintyOptimization
from gpder.bayes.minimizers import hybrid_minimizer

from gpder.gaussian_process import GaussianProcessRegressor
from gpder.gaussian_process.kernels import GPKernelDerAware, GPKernel

from sklearn.metrics import mean_squared_error

from utils import plot_gpr_evolution, plot_gpr_iterloss
from utils import grid_sampling

# %% [markdown]
# We regress the same function as in the 'Gaussian Process' demo, but instead of randomly selecting training points for the GPR, we rely on a Bayesian optimization to find the training points which minimize the uncertainty of the model.

# %%
def F(X, s=0.1):
    noise = s * np.random.uniform(-1, 1)
    return X * np.sin(4*np.pi * X**2) + s

# %%
np.random.seed(1)

X_lower = 0 
X_upper = 1
X_star = np.linspace(X_lower, X_upper, 50)
y_star = F(X_star)

plt.plot(X_star, y_star, label='Function to regress')
plt.xlabel("X", fontsize=14)
plt.ylabel("F", fontsize=14)
plt.legend(fontsize=14)
plt.show()

# %% [markdown]
# ## Regular GPR
#
# We begin by minimizing the uncertainty of a regular GPR regression.
#
# To kick off the search, we begin with one randomly selected training point. With every iteration, we sample the point which is predicted to minimize the uncertainty. That is, the nth point is chosen to minimize the uncertainty of the model with n-training points.

# %%
bayes_reg = UncertaintyOptimization(fun=F,
                                    verbose=True,
                                    param_bounds={'X': (0, 1)},
                                    random_state=123)
bayes_reg.minimize_uncertainty(nrand_train=5,
                               params_val=X_star.reshape(-1, 1),
                               niters=8,
                               minimizer_restarts=5,
                               gp_optimizer_restarts=10)

bayes_reg_mse = bayes_reg.mse_val
bayes_reg_uncert = bayes_reg.uncert_val

# plot the bayesian search at every iteration
plot_gpr_evolution(bayes=copy.deepcopy(bayes_reg), 
                   save_to="reg_gpr_evol.png")

# and the MSE, Uncertainty per iteration
plot_gpr_iterloss(mse=bayes_reg_mse, 
                  uncert=bayes_reg_uncert,
                  save_to="reg_metricsvsiter.png")
# Out:
# | Iter | X         | Target    | MSE val   | Uncert val|
# ...
# | 1    | 0.696469  | -0.029909 | 0.134436  | 2.396539  |
# | 2    | 0.286139  | 0.345142  | 0.134436  | 2.396539  |
# | 3    | 0.226851  | 0.236688  | 0.134436  | 2.396539  |
# | 4    | 0.551315  | -0.245775 | 0.134436  | 2.396539  |
# | 5    | 0.719469  | 0.258144  | 0.134436  | 2.396539  |
# | 6    | 1.000000  | 0.100000  | 0.142159  | 2.017558  |
# | 7    | 0.000000  | 0.100000  | 0.142774  | 1.752975  |
# | 8    | 0.658224  | -0.389565 | 0.116768  | 1.933283  |
# | 9    | 0.874752  | -0.065974 | 0.174126  | 2.635681  |
# | 10   | 0.370998  | 0.466328  | 0.174335  | 3.472490  |
# | 11   | 0.362718  | 0.461485  | 0.066047  | 0.892838  |
# | 12   | 0.102551  | 0.113513  | 0.066341  | 0.503506  |
# | 13   | 0.806884  | 0.863995  | 0.018607  | 0.440383  |

# %% [markdown]
# And now let's compare the results to uniformly sampling points.

# %%
grid_mse, grid_uncert = grid_sampling(niters=8, 
                                      x_init=bayes_hyb.init_params, 
                                      x_val=X_star, 
                                      bound_low=0, bound_high=1,
                                      fun=F,
                                      save_to='grid_gpr_evol.png')

plot_gpr_iterloss(grid_mse, grid_uncert, save_to='grid_metricsvsiter')

# %%
plt.plot(mse_scipy, label='lbfgs')
plt.plot(mse_hybrid, label='hybrid')
plt.plot(mse_grid, label='grid')
plt.ylabel("MSE", fontsize=14)
plt.legend(fontsize=14)
plt.show()

plt.plot(uncert_scipy, label='lbfgs')
plt.plot(uncert_hybrid, label='hybrid')
plt.plot(uncert_grid, label='grid')
plt.ylabel("Uncert", fontsize=14)
plt.legend(fontsize=14)
plt.show()

# %% [markdown]
# ## Derivative-enhanced GPR

# %%
def dF(X, s=0.1):
    noise = s * np.random.uniform(-1, 1)
    return np.sin(4*np.pi * X**2) + X * np.cos(4*np.pi * X**2) * (8*np.pi * X) + s

# %% [markdown]
# ##### scipy

# %%
bayes_der_scp = UncertaintyOptimization(fun=F,
                                dfun=dF,
                                verbose=True,
                                param_bounds={'X': (0, 1)},
                                ignore_convergence_warnings=True,
                                random_state=123)

bayes_der_scp.minimize_uncertainty(nrand_train=5,
                           params_val=X_star.reshape(-1, 1),
                           niters=8,
                           minimizer_restarts=5,
                           gp_optimizer_restarts=10)

plot_gpr_evolution(bayes=copy.deepcopy(bayes_der_scp), saveto="deriv_reg_scp")
plot_gpr_iterloss(bayes=copy.deepcopy(bayes_der_scp), saveto="deriv_loss_scp")

mse_scipy_deriv = bayes_der_scp.mse_val
uncert_scipy_deriv = bayes_der_scp.uncert_val
# Out:
# | Iter | X         | Target    | MSE val   | Uncert val|
# ...
# | 1    | 0.696469  | -0.029909 | 0.177286  | 2.304318  |
# | 2    | 0.286139  | 0.345142  | 0.177286  | 2.304318  |
# | 3    | 0.226851  | 0.236688  | 0.177286  | 2.304318  |
# | 4    | 0.551315  | -0.245775 | 0.177286  | 2.304318  |
# | 5    | 0.719469  | 0.258144  | 0.177286  | 2.304318  |
# | 6    | 1.000000  | 0.100000  | 0.009647  | 4.084409  |
# | 7    | 0.000000  | 0.100000  | 0.008905  | 1.224879  |
# | 8    | 0.482241  | 0.204865  | 0.006322  | 0.238968  |
# | 9    | 0.140805  | 0.134718  | 0.000956  | 0.091847  |
# | 10   | 0.342869  | 0.441371  | 0.003917  | 0.063003  |
# | 11   | 0.584588  | -0.434274 | 0.003609  | 0.068613  |
# | 12   | 0.866666  | 0.087915  | 0.000096  | 0.001520  |
# | 13   | 0.228988  | 0.240202  | 0.000095  | 0.001476  |

# %% [markdown]
# ##### hybrid

# %%
bayes_hyb = UncertaintyOptimization(fun=F,
                                dfun=dF,
                                verbose=True,
                                param_bounds={'X': (0, 1)},
                                ignore_convergence_warnings=True,
                                random_state=123)

bayes_hyb.minimize_uncertainty(nrand_train=5,
                           minimizer=minimizer,
                           params_val=X_star.reshape(-1, 1),
                           niters=8,
                           minimizer_restarts=5,
                           gp_optimizer_restarts=10)

plot_gpr_evolution(bayes=copy.deepcopy(bayes_hyb), saveto="deriv_reg_hyb")
plot_gpr_iterloss(bayes=copy.deepcopy(bayes_hyb), saveto="deriv_loss_hyb")

mse_hybrid_deriv = bayes_hyb.mse_val
uncert_hybrid_deriv = bayes_hyb.uncert_val
# Out:
# | Iter | X         | Target    | MSE val   | Uncert val|
# ...
# | 1    | 0.696469  | -0.029909 | 0.177286  | 2.304318  |
# | 2    | 0.286139  | 0.345142  | 0.177286  | 2.304318  |
# | 3    | 0.226851  | 0.236688  | 0.177286  | 2.304318  |
# | 4    | 0.551315  | -0.245775 | 0.177286  | 2.304318  |
# | 5    | 0.719469  | 0.258144  | 0.177286  | 2.304318  |
# | 6    | 1.003591  | 0.190605  | 0.006753  | 4.050225  |
# | 7    | 0.000000  | 0.100000  | 0.005888  | 1.051905  |
# | 8    | 0.486480  | 0.181151  | 0.004886  | 0.266644  |
# | 9    | 0.847745  | 0.425185  | 0.000431  | 0.025652  |
# | 10   | 0.390389  | 0.467469  | 0.000295  | 0.019878  |
# | 11   | 0.957239  | -0.731154 | 0.000132  | 0.051940  |
# | 12   | 0.125716  | 0.124804  | 0.000004  | 0.001367  |
# | 13   | 0.125252  | 0.124533  | 0.000014  | 0.002996  |

# %% [markdown]
# ##### grid

# %%
mse_grid_deriv, uncert_grid_deriv = grid_sampling(niters=8, 
                                        x_init=bayes_hyb.init_params, 
                                        x_val=X_star, 
                                        bound_low=0, bound_high=1,
                                        fun=F,
                                        dfun=dF,
                                        saveto='deriv_grid')

# %%
plt.plot(mse_scipy_deriv, label='lbfgs')
plt.plot(mse_hybrid_deriv, label='hybrid')
plt.plot(mse_grid_deriv, label='grid')
plt.ylabel("MSE", fontsize=14)
plt.legend(fontsize=14)
plt.savefig("all_mse_compare.png", bbox_inches='tight')
plt.show()

plt.plot(uncert_scipy_deriv, label='lbfgs')
plt.plot(uncert_hybrid_deriv, label='hybrid')
plt.plot(uncert_grid_deriv, label='grid')
plt.ylabel("Uncert", fontsize=14)
plt.legend(fontsize=14)
plt.savefig("all_uncert_compare.png", bbox_inches='tight')
plt.show()

# %%
def grid_sampling(niters, x_init, x_val,
                  bound_low, bound_high,
                  fun, dfun=None, saveto=None):
    y_init = fun(x_init)
    if dfun is not None:
        dx_init = x_init
        dy_init = dfun(dx_init)

    fig, axs = plt.subplots(niters+1, figsize=(8, (niters+1)*1.5), sharex=True)

    x_train = x_init
    y_train = fun(x_train)
    if dfun is not None:
        dx_train = x_train
        dy_train = dfun(dx_train)

    params_val = x_val.reshape(-1, 1)
    targets_val = fun(x_val)

    y_val = fun(x_val)

    if dfun is not None:
        kernel = GPKernelDerAware()
    else:
        kernel = GPKernel()
    gpr = GaussianProcessRegressor(kernel=kernel,
                                   ignore_convergence_warnings=True,
                                   n_restarts_optimizer=10,
                                   random_state=123)
    if dfun is not None:
        gpr.fit(x_train.reshape(-1, 1), y_train,
                dx_train.reshape(-1, 1), dy_train)
    else:
        gpr.fit(x_train.reshape(-1, 1), y_train)

    # predict X_star
    mu, cov = gpr.predict(x_val.reshape(-1, 1), return_cov=True)
    _, std = gpr.predict(x_val.reshape(-1, 1), return_std=True)
    mu = mu.ravel()
    uncert95 = 1.96*std

    axs[0].scatter(x_train, y_train,
                   color='green', label='Initial pts', marker='x')
    axs[0].fill_between(params_val.reshape(-1,),
                        mu-uncert95, mu+uncert95, alpha=0.2)
    axs[0].plot(params_val, mu, color='navy', label='Pred')
    axs[0].plot(params_val, targets_val, color='blueviolet', label='True')
    axs[0].legend(loc='upper center',
                  ncol=3,
                  bbox_to_anchor=(0.5, 1.7))

    mse_grid = [mean_squared_error(y_val, mu)]
    uncert_grid = [np.trace(cov)]

    for i in range(niters):
        bound_low = 0
        bound_high = 1
        dpts = (bound_high - bound_low) / (i + 2)
        #x_grid = np.array([bound_low + dpts*(j) for j in range(1, i + 2)]).reshape(-1, 1)
        x_grid = np.linspace(bound_low, bound_high, i+1).reshape(-1, 1)
        y_grid = fun(x_grid)

        x_train = np.concatenate((x_init, x_grid))
        y_train = fun(x_train)
        if dfun is not None:
            dx_train = x_train
            dy_train = dfun(dx_train)

        if dfun is not None:
            kernel = GPKernelDerAware()
        else:
            kernel = GPKernel()
        gpr = GaussianProcessRegressor(kernel=kernel,
                                       ignore_convergence_warnings=True,
                                       n_restarts_optimizer=10,
                                       random_state=123)
        if dfun is not None:
            gpr.fit(x_train.reshape(-1, 1), y_train,
                    dx_train.reshape(-1, 1), dy_train)
        else:
            gpr.fit(x_train.reshape(-1, 1), y_train)

        # predict X_star
        mu, cov = gpr.predict(x_val.reshape(-1, 1), return_cov=True)
        _, std = gpr.predict(x_val.reshape(-1, 1), return_std=True)
        mu = mu.ravel()
        uncert95 = 1.96*std

        mse_grid.append(mean_squared_error(y_val, mu))
        uncert_grid.append(np.trace(cov))

        ii = i+1  # plot axis
        axs[ii].scatter(x_init, y_init,
                        color='green', marker='x', label='Iter {}'.format(i+1))
        axs[ii].scatter(x_grid, y_grid,
                        color='red', marker='*')
        axs[ii].fill_between(params_val.reshape(-1,),
                             mu-uncert95, mu+uncert95, alpha=0.2)
        axs[ii].plot(params_val, mu, color='navy')
        axs[ii].plot(params_val, targets_val, color='blueviolet')
        axs[ii].legend(markerscale=0, handletextpad=-2)

    if saveto is not None:
        plt.savefig(saveto + "reg.png", bbox_inches='tight')

    # loss plot
    fig, ax = plt.subplots(1, 2, figsize=(12, 3))
    ax[0].plot(mse_grid)
    ax[0].set_xlabel("Iter", fontsize=14)
    ax[0].set_ylabel("MSE", fontsize=14)
    ax[1].plot(uncert_grid)
    ax[1].set_xlabel("Iter", fontsize=14)
    ax[1].set_ylabel("Uncert", fontsize=14)

    if saveto is not None:
        plt.savefig(saveto + "loss.png", bbox_inches='tight')

    return mse_grid, uncert_grid
