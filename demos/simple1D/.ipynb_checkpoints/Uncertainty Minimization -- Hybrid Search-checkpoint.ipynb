# %% [markdown]
# # Bayesian Uncertainty Minimization
#
# This demo shows how to minimize the uncertainty of a simple 1D function using Bayesian optimization with a GPR as the surrogate model. The GPR can use derivative information to aid in the regression.

# %%
import sys 
import numpy as np
import matplotlib.pyplot as plt
import time
import copy

sys.path.append("../..")
import gpder 
from gpder import UncertaintyOptimization

from utils import plot_gpr_evolution, plot_gpr_iterloss

# %% [markdown]
# We regress the same function as in the 'Gaussian Process' demo, but instead of randomly selecting training points for the GPR, we rely on a Bayesian optimization to find the training points which minimize the uncertainty of the model.

# %%
def F(X, s=0.1):
    noise = s * np.random.uniform(-1, 1)
    return X * np.sin(4*np.pi * X**2) + s

# %%
np.random.seed(1)

X_lower = 0 
X_upper = 1
X_star = np.linspace(X_lower, X_upper, 50)
y_star = F(X_star)

plt.plot(X_star, y_star, label='Function to regress')
plt.xlabel("X", fontsize=14)
plt.ylabel("F", fontsize=14)
plt.legend(fontsize=14)
plt.show()

# %% [markdown]
# ## Regular GPR
#
# We begin by minimizing the uncertainty of a regular GPR regression.
#
# To kick off the search, we begin with one randomly selected training point. With every iteration, we sample the point which is predicted to minimize the uncertainty. That is, the nth point is chosen to minimize the uncertainty of the model with n-training points.

# %%
bayes = UncertaintyOptimization(fun=F,
                                verbose=True,
                                param_bounds={'X': (0, 1)},
                                random_state=1)
bayes.minimize_uncertainty(nrand_train=3,
                           #minimizer=minimizer,
                           gamma=0,
                           params_val=X_star.reshape(-1, 1),
                           niters=10,
                           minimizer_restarts=5,
                           gp_optimizer_restarts=10)

plot_gpr_evolution(bayes=copy.deepcopy(bayes))
plot_gpr_iterloss(bayes=copy.deepcopy(bayes))
# Out:
# | Iter | X         | Target    | Uncert    | MSE val   | Uncert val|
# ====================================================================
# | 1    | 0.417022  | 0.440712  | 0.214622  | 0.187816  | 0.166741  |
# | 2    | 0.720324  | 0.269189  | 0.214622  | 0.187816  | 0.166741  |
# | 3    | 0.000114  | 0.100000  | 0.214622  | 0.187816  | 0.166741  |
# | 4    | 1.000000  | 0.100000  | 0.236681  | 0.190598  | 0.018368  |
# | 5    | 0.051366  | 0.101703  | 0.263367  | 0.190009  | 0.101904  |
# | 6    | 0.061725  | 0.102954  | 0.307633  | 0.168824  | 1.157291  |
# | 7    | 0.999863  | 0.096565  | 0.365522  | 0.195757  | 0.027185  |
# | 8    | 0.968163  | -0.585976 | 0.802359  | 0.136034  | 3.954011  |
# | 9    | 0.174089  | 0.164710  | 0.807614  | 0.136023  | 3.416676  |
# | 10   | 0.805176  | 0.870882  | 2.000577  | 0.054929  | 5.717998  |
# | 11   | 0.551593  | -0.247601 | 1.919029  | 0.057544  | 4.896078  |
# | 12   | 0.289957  | 0.352450  | 2.004302  | 0.049430  | 4.389822  |
# | 13   | 0.634853  | -0.495853 | 2.328405  | 0.023991  | 3.898985  |

# %%
bayes = UncertaintyOptimization(fun=F,
                                verbose=True,
                                param_bounds={'X': (0, 1)},
                                random_state=1)
bayes.minimize_uncertainty(nrand_train=5,
                           #minimizer=minimizer,
                           gamma=0,
                           params_val=X_star.reshape(-1, 1),
                           niters=10,
                           minimizer_restarts=5,
                           gp_optimizer_restarts=10)

plot_gpr_evolution(bayes=copy.deepcopy(bayes))
plot_gpr_iterloss(bayes=copy.deepcopy(bayes))
# Out:
# | Iter | X         | Target    | Uncert    | MSE val   | Uncert val|
# ====================================================================
# | 1    | 0.417022  | 0.440712  | 0.330763  | 0.189079  | 0.337042  |
# | 2    | 0.720324  | 0.269189  | 0.330763  | 0.189079  | 0.337042  |
# | 3    | 0.000114  | 0.100000  | 0.330763  | 0.189079  | 0.337042  |
# | 4    | 0.302333  | 0.375789  | 0.330763  | 0.189079  | 0.337042  |
# | 5    | 0.146756  | 0.139236  | 0.330763  | 0.189079  | 0.337042  |
# | 6    | 1.000000  | 0.100000  | 0.447306  | 0.179079  | 1.258718  |
# | 7    | 0.665004  | -0.341460 | 0.563888  | 0.164404  | 3.587514  |
# | 8    | 0.623360  | -0.514308 | 0.828402  | 0.174493  | 5.177509  |
# | 9    | 0.352485  | 0.452470  | 0.910616  | 0.074401  | 1.463274  |
# | 10   | 0.027792  | 0.100270  | 0.977732  | 0.070292  | 1.100424  |
# | 11   | 0.881174  | -0.187700 | 0.949742  | 0.072457  | 0.755503  |
# | 12   | 0.810380  | 0.846864  | 1.961307  | 0.017544  | 1.010715  |
# | 13   | 0.981859  | -0.328670 | 1.903618  | 0.172284  | 7.314634  |
# | 14   | 0.223411  | 0.231118  | 2.542885  | 0.010558  | 2.037402  |
# | 15   | 0.798280  | 0.888839  | 2.747068  | 0.164398  | 8.579521  |

# %% [markdown]
# ## Derivative-enhanced GPR

# %%
def dF(X, s=0.1):
    noise = s * np.random.uniform(-1, 1)
    return np.sin(4*np.pi * X**2) + X * np.cos(4*np.pi * X**2) * (8*np.pi * X) + s

# %%
bayes = UncertaintyOptimization(fun=F,
                                dfun=dF,
                                verbose=True,
                                param_bounds={'X': (0, 1)},
                                ignore_convergence_warnings=True,
                                random_state=1)

bayes.minimize_uncertainty(nrand_train=3,
                           gamma=0,
                           params_val=X_star.reshape(-1, 1),
                           niters=10,
                           minimizer_restarts=5,
                           gp_optimizer_restarts=10)

plot_gpr_evolution(bayes=copy.deepcopy(bayes))
plot_gpr_iterloss(bayes=copy.deepcopy(bayes))
# Out:
# | Iter | X         | Target    | Uncert    | MSE val   | Uncert val|
# ====================================================================
# | 1    | 0.417022  | 0.440712  | 171.935380| 0.185120  | 1.846933  |
# | 2    | 0.720324  | 0.269189  | 171.935380| 0.185120  | 1.846933  |
# | 3    | 0.000114  | 0.100000  | 171.935380| 0.185120  | 1.846933  |
# | 4    | 0.012336  | 0.100024  | 205.779076| 0.190970  | 0.231530  |
# | 5    | 0.130646  | 0.127807  | 128.722711| 0.342137  | 2.604364  |
# | 6    | 1.000000  | 0.100000  | 809.407023| 0.169490  | 1.120427  |
# | 7    | 0.474395  | 0.246308  | 504.903673| 0.032520  | 1.573071  |
# | 8    | 0.774463  | 0.835935  | 1220.796270| 0.003428  | 0.025595  |
# | 9    | 0.216606  | 0.220438  | 1806.934310| 0.004661  | 0.013283  |
# | 10   | 0.004740  | 0.100001  | 793.955318| 0.000967  | 0.049815  |
# | 11   | 0.300248  | 0.371912  | 2646.902352| 0.005676  | 0.008956  |
# | 12   | 0.547116  | -0.217880 | 2129.663643| 0.003350  | 0.008429  |
# | 13   | 0.652016  | -0.426889 | 2356.142419| 0.003553  | 0.007075  |

# %%
from gpder.gaussian_process import GaussianProcessRegressor
from gpder.gaussian_process.kernels import GPKernelDerAware

from sklearn.metrics import mean_squared_error

from utils import plot_gpr

# %%
x_train = np.vstack((bayes.init_params, np.linspace(0, 1, 5).reshape(-1, 1)))
y_train = F(x_train)
dx_train = x_train
dy_train = dF(x_train)

kernel = GPKernelDerAware()
gpr = GaussianProcessRegressor(kernel=kernel,
                               ignore_convergence_warnings=True,
                               n_restarts_optimizer=10,
                               random_state=123)
gpr.fit(x_train.reshape(-1, 1), y_train,
        dx_train.reshape(-1, 1), dy_train)

# predict X_star
mu, cov = gpr.predict(X_star.reshape(-1, 1), return_cov=True)
_, std = gpr.predict(X_star.reshape(-1, 1), return_std=True)
mu = mu.ravel()

mse = mean_squared_error(y_star, mu)
print("MSE : ", mse)
print("Uncert : ", np.trace(cov))

# nsamples = 3
# samples = np.random.multivariate_normal(mu, cov, nsamples)
samples = []

plot_gpr(X_train=x_train, y_train=y_train, 
         X_true=X_star, y_true=y_star, 
         y_pred=mu, std_pred=std, samples=samples)
# Out:
# MSE :  0.0003279857936171498
# Uncert :  0.1401012307513516

# %%
x_train = np.vstack((bayes.init_params, np.linspace(0, 1, 5).reshape(-1, 1)))
y_train = F(x_train)
dx_train = x_train
dy_train = dF(x_train)

# -- uniform -- #
kernel = GPKernelDerAware()
gpr = GaussianProcessRegressor(kernel=kernel,
                               ignore_convergence_warnings=True,
                               n_restarts_optimizer=10,
                               random_state=123)
gpr.fit(x_train.reshape(-1, 1), y_train,
        dx_train.reshape(-1, 1), dy_train)

mu_rand, cov_rand = gpr.predict(X_star.reshape(-1, 1), return_cov=True)
_, std_rand = gpr.predict(X_star.reshape(-1, 1), return_std=True)
mu_rand = mu_rand.ravel()

mse_rand = mean_squared_error(y_star, mu_rand)
print("MSE : ", mse_rand)
print("Uncert : ", np.trace(cov_rand))


# -- bayes -- #
kernel = GPKernelDerAware()
gpr = GaussianProcessRegressor(kernel=kernel,
                               ignore_convergence_warnings=True,
                               n_restarts_optimizer=10,
                               random_state=123)
gpr.fit(bayes.params.reshape(-1, 1), bayes.targets,
        bayes.params.reshape(-1, 1), bayes.dtargets)

mu_bayes, cov_bayes = gpr.predict(X_star.reshape(-1, 1), return_cov=True)
_, std_bayes = gpr.predict(X_star.reshape(-1, 1), return_std=True)
mu_bayes = mu_bayes.ravel()

mse_bayes= mean_squared_error(y_star, mu_bayes)
print("MSE : ", mse_bayes)
print("Uncert : ", np.trace(cov_bayes))

# nsamples = 3
# samples = np.random.multivariate_normal(mu, cov, nsamples)
samples = []

plot_gpr(X_train=x_train, y_train=y_train, 
         X_true=X_star, y_true=y_star, 
         y_pred=mu_rand, std_pred=std_rand, samples=samples)


plot_gpr(X_train=x_train, y_train=y_train, 
         X_true=X_star, y_true=y_star, 
         y_pred=mu_bayes, std_pred=std_bayes, samples=samples)
# Out:
# MSE :  0.0003279857936171498
# Uncert :  0.1401012307513516
# MSE :  0.0035528016126098777
# Uncert :  0.007074602128909646
