# %% [markdown]
# # Bayesian Uncertainty Minimization

# %%
import sys 
import numpy as np
import matplotlib.pyplot as plt
import time
import copy

sys.path.append("../..")
import gpder 
from gpder import UncertaintyOptimization
from gpder.bayes.minimizers import hybrid_minimizer

from utils import plot_gpr_evolution, plot_gpr_iterloss

# %%
import sys 
import numpy as np
import matplotlib.pyplot as plt

from sklearn.metrics import mean_squared_error

sys.path.append("../..")
import gpder
from gpder.gaussian_process import GaussianProcessRegressor
from gpder.gaussian_process.kernels import GPKernel, GPKernelDerAware

try:
    import uproot
except:
    print("uproot must be installed to run this demo.")

# %%
f = uproot.open("./three_jets.root")
tree = f['tnt']

njets = np.array(tree['nj'])
njets_cut = np.where(njets < 4)

j1_threeM = np.stack((np.array(tree['j1_pt'])[njets_cut],
                      np.array(tree['j1_eta'])[njets_cut],
                      np.array(tree['j1_phi'])[njets_cut]), axis=1)

j2_threeM = np.stack((np.array(tree['j2_pt'])[njets_cut],
                      np.array(tree['j2_eta'])[njets_cut],
                      np.array(tree['j2_phi'])[njets_cut]), axis=1)

j3_threeM = np.stack((np.array(tree['j3_pt'])[njets_cut],
                      np.array(tree['j3_eta'])[njets_cut],
                      np.array(tree['j3_phi'])[njets_cut]), axis=1)

f.close()

# %%
def sigmoid(X):
    return 1. / (1. + np.exp(-X))

# %%
def Eff_MET50_sigmoid(J_scale, j_scale, 
                      j1_threeM=j1_threeM, 
                      j2_threeM=j2_threeM, 
                      j3_threeM=j3_threeM):
    count_met = 0
    count_pTcut = 0
    for i in range(len(j1_threeM)):
        # -- pT -- # 
        j1_pt = j1_threeM[i, 0] / J_scale
        j2_pt = j2_threeM[i, 0] / j_scale
        j3_pt = j3_threeM[i, 0] / j_scale
        if (j1_pt > 200 and j2_pt  < 200):
            count_pTcut += 1
            # -- pT_x decomp -- # 
            j1_pt_x = j1_pt * np.cos(j1_threeM[i, 2])
            j2_pt_x = j2_pt * np.cos(j2_threeM[i, 2])
            j3_pt_x = j3_pt * np.cos(j3_threeM[i, 2])
            # -- pT_y decomp -- #
            j1_pt_y = j1_pt * np.sin(j1_threeM[i, 2])
            j2_pt_y = j2_pt * np.sin(j2_threeM[i, 2])
            j3_pt_y = j3_pt * np.sin(j3_threeM[i, 2])
            # -- MET -- #
            met_x = j1_pt_x + j2_pt_x + j3_pt_x
            met_y = j1_pt_y + j2_pt_y + j3_pt_y
            met = np.sqrt(met_x * met_x + met_y * met_y)

            count_met += sigmoid(-(met-50.0))

    return count_met / count_pTcut

# %% [markdown]
# ### Regular GPR

# %%
# -- training points -- # 
nu_a_train = [0.9, 1.0, 1.0, 1.0, 1.1]
nu_j_train = [1.0, 0.9, 1.0, 1.1, 1.0]
X_train = np.vstack((nu_a_train, nu_j_train)).T

y_train = np.array([Eff_MET50_sigmoid(X_train[i][0], 
                                      X_train[i][1]) for i in range(len(X_train))])
y_train_sig = np.array([Eff_MET50_sigmoid(X_train[i][0], 
                                          X_train[i][1]) for i in range(len(X_train))])

# -- testing points -- # 
res=10
X_lower = 0.5
X_upper = 1.5
lin = np.linspace(X_lower, X_upper, res)
nu_a_test, nu_j_test = np.meshgrid(lin, lin)
X_test = np.vstack((nu_a_test.flatten(), nu_j_test.flatten())).T 
y_test = np.array([Eff_MET50_sigmoid(X_test[i][0], X_test[i][1]) for i in range(len(X_test))])
y_test_sig = np.array([Eff_MET50_sigmoid(X_test[i][0], X_test[i][1]) for i in range(len(X_test))])

# %%
bayes = UncertaintyOptimization(fun=Eff_MET50_sigmoid,
                                ignore_convergence_warnings=True,
                                verbose=True,
                                param_bounds={'J_scale': (0.5, 1.5), 
                                              'j_scale': (0.5, 1.5)},
                                random_state=123)
bayes.minimize_uncertainty(params_train=X_train,
                           #minimizer=minimizer,
                           gamma=0,
                           params_val=X_test,
                           niters=8,
                           minimizer_restarts=5,
                           gp_optimizer_restarts=10)

plot_gpr_evolution(bayes=copy.deepcopy(bayes), X_lower=0.5, X_upper=1.5)
plot_gpr_iterloss(bayes=copy.deepcopy(bayes))
# Out:
# | Iter | J_scale   | j_scale   | Target    | Uncert    | MSE val   | Uncert val|
# ================================================================================
# | 1    | 0.900000  | 1.000000  | 0.580745  | 0.972420  | 0.079015  | 8.479940  |
# | 2    | 1.000000  | 0.900000  | 0.787183  | 0.972420  | 0.079015  | 8.479940  |
# | 3    | 1.000000  | 1.000000  | 0.780826  | 0.972420  | 0.079015  | 8.479940  |
# | 4    | 1.000000  | 1.100000  | 0.661358  | 0.972420  | 0.079015  | 8.479940  |
# | 5    | 1.100000  | 1.000000  | 0.834261  | 0.972420  | 0.079015  | 8.479940  |
# | 6    | 1.500000  | 1.500000  | 0.871208  | 4.924758  | 0.240493  | 1.811604  |
# | 7    | 1.500000  | 1.500000  | 0.871208  | 5.902252  | 0.245699  | 1.515354  |
# | 8    | 1.500000  | 1.500000  | 0.871208  | 2.484912  | 0.029776  | 11.048018 |
# | 9    | 1.500000  | 0.500001  | 0.000000  | 2.296861  | 0.027782  | 8.050488  |
# | 10   | 0.500000  | 0.500000  | 0.095242  | 2.163528  | 0.022047  | 6.001629  |
# | 11   | 0.500000  | 1.500000  | 0.000000  | 2.055952  | 0.020616  | 4.420891  |
# | 12   | 0.500000  | 1.016336  | 0.000001  | 2.018746  | 0.020008  | 3.573971  |
# | 13   | 0.950561  | 1.500000  | 0.007827  | 2.043493  | 0.019534  | 2.695397  |

# %% [markdown]
# ### With derivatives

# %%
def dsigmoid(X):
    return sigmoid(X) * (1 - sigmoid(X))

# %%
def dEff_MET50_sigmoid(J_scale, j_scale, 
              j1_threeM=j1_threeM, j2_threeM=j2_threeM, j3_threeM=j3_threeM):
    dmet_dj1 = 0
    dmet_dj2j3 = 0
    count_pTcut = 0
    for i in range(len(j1_threeM)):
        # -- pT -- # 
        j1_pt = j1_threeM[i, 0] / J_scale
        j2_pt = j2_threeM[i, 0] / j_scale
        j3_pt = j3_threeM[i, 0] / j_scale
        if (j1_pt > 200 and j2_pt  < 200):
            count_pTcut += 1
            # -- pT_x decomp -- # 
            j1_pt_x = j1_pt * np.cos(j1_threeM[i, 2])
            j2_pt_x = j2_pt * np.cos(j2_threeM[i, 2])
            j3_pt_x = j3_pt * np.cos(j3_threeM[i, 2])
            # -- pT_y decomp -- #
            j1_pt_y = j1_pt * np.sin(j1_threeM[i, 2])
            j2_pt_y = j2_pt * np.sin(j2_threeM[i, 2])
            j3_pt_y = j3_pt * np.sin(j3_threeM[i, 2])
            # -- MET -- #
            met_x = j1_pt_x + j2_pt_x + j3_pt_x
            met_y = j1_pt_y + j2_pt_y + j3_pt_y
            met = np.sqrt(met_x * met_x + met_y * met_y)

            dsig = -dsigmoid(-(met-50.0))
            dmet = 0.5 / met

            # wrt J_scale 
            dj1  = -2*met_x*j1_threeM[i, 0] * np.cos(j1_threeM[i, 2]) / J_scale**2
            dj1 += -2*met_y*j1_threeM[i, 0] * np.sin(j1_threeM[i, 2]) / J_scale**2
            # wrt j_scale
            dj2j3  = -2*met_x*j2_threeM[i, 0] * np.cos(j2_threeM[i, 2]) / j_scale**2
            dj2j3 += -2*met_x*j3_threeM[i, 0] * np.cos(j3_threeM[i, 2]) / j_scale**2
            dj2j3 += -2*met_y*j2_threeM[i, 0] * np.sin(j2_threeM[i, 2]) / j_scale**2
            dj2j3 += -2*met_y*j3_threeM[i, 0] * np.sin(j3_threeM[i, 2]) / j_scale**2

            dmet_dj1   += dsig * dmet * dj1
            dmet_dj2j3 += dsig * dmet * dj2j3

    return [dmet_dj1 / count_pTcut, dmet_dj2j3 / count_pTcut]

# %%
dX_train = X_train
dy_train_sig = np.array([dEff_MET50_sigmoid(dX_train[i][0], 
                                            dX_train[i][1]) for i in range(len(dX_train))])

# %%
def minimizer(fun, bounds):
    return hybrid_minimizer(fun, bounds, 
                            N_rand=10, 
                            N_brute=3)

# %%
bayes = UncertaintyOptimization(fun=Eff_MET50_sigmoid,
                                dfun=dEff_MET50_sigmoid,
                                ignore_convergence_warnings=True,
                                verbose=True,
                                param_bounds={'J_scale': (0.5, 1.5), 
                                              'j_scale': (0.5, 1.5)},
                                random_state=123)
bayes.minimize_uncertainty(params_train=X_train,
                           #minimizer=minimizer,
                           gamma=0,
                           params_val=X_test,
                           niters=8,
                           minimizer_restarts=5,
                           gp_optimizer_restarts=10)

plot_gpr_evolution(bayes=copy.deepcopy(bayes), X_lower=0.5, X_upper=1.5)
plot_gpr_iterloss(bayes=copy.deepcopy(bayes))
# Out:
# | Iter | J_scale   | j_scale   | Target    | Uncert    | MSE val   | Uncert val|
# ================================================================================
# | 1    | 0.900000  | 1.000000  | 0.580745  | 51.072517 | 0.082897  | 13.804135 |
# | 2    | 1.000000  | 0.900000  | 0.787183  | 51.072517 | 0.082897  | 13.804135 |
# | 3    | 1.000000  | 1.000000  | 0.780826  | 51.072517 | 0.082897  | 13.804135 |
# | 4    | 1.000000  | 1.100000  | 0.661358  | 51.072517 | 0.082897  | 13.804135 |
# | 5    | 1.100000  | 1.000000  | 0.834261  | 51.072517 | 0.082897  | 13.804135 |
# | 6    | 0.500000  | 0.500000  | 0.095242  | 40.253426 | 0.062830  | 7.587517  |
# | 7    | 1.499999  | 1.499999  | 0.871208  | 50.603047 | 0.072842  | 6.320426  |
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-076fe927a07c> in <module>
#      11                            niters=8,
#      12                            minimizer_restarts=5,
# ---> 13                            gp_optimizer_restarts=10)
#      14
#      15 plot_gpr_evolution(bayes=copy.deepcopy(bayes), X_lower=0.5, X_upper=1.5)
#
# ~/Desktop/gpder/gpder/bayes/bayesian_opt_uncertainty.py in minimize_uncertainty(self, params_train, nrand_train, params_val, minimizer, gamma, niters, minimizer_restarts, gp_optimizer_restarts, workers)
#     208             # propose the next sampling location
#     209             param_next, uncert_next = self._find_next_location(
# --> 210                 n_restarts=self.minimizer_restarts)
#     211
#     212             # add proposed location to the training set
#
# ~/Desktop/gpder/gpder/bayes/bayesian_opt_uncertainty.py in _find_next_location(self, n_restarts)
#     385                     res = optimize.minimize(
#     386                         fun=global_uncert, x0=x0, method='L-BFGS-B',
# --> 387                         bounds=self._params_bounds_vals)
#     388                     fval = res.fun[0]
#     389                     x = res.x
#
# ~/.virtualenvs/python3_ml/lib/python3.6/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     608     elif meth == 'l-bfgs-b':
#     609         return _minimize_lbfgsb(fun, x0, args, jac, bounds,
# --> 610                                 callback=callback, **options)
#     611     elif meth == 'tnc':
#     612         return _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#
# ~/.virtualenvs/python3_ml/lib/python3.6/site-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, **unknown_options)
#     343             # until the completion of the current minimization iteration.
#     344             # Overwrite f and g:
# --> 345             f, g = func_and_grad(x)
#     346         elif task_str.startswith(b'NEW_X'):
#     347             # new iteration
#
# ~/.virtualenvs/python3_ml/lib/python3.6/site-packages/scipy/optimize/lbfgsb.py in func_and_grad(x)
#     288     if jac is None:
#     289         def func_and_grad(x):
# --> 290             f = fun(x, *args)
#     291             g = _approx_fprime_helper(x, fun, epsilon, args=args, f0=f)
#     292             return f, g
#
# ~/.virtualenvs/python3_ml/lib/python3.6/site-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     325     def function_wrapper(*wrapper_args):
#     326         ncalls[0] += 1
# --> 327         return function(*(wrapper_args + args))
#     328
#     329     return ncalls, function_wrapper
#
# ~/Desktop/gpder/gpder/bayes/bayesian_opt_uncertainty.py in global_uncert(X)
#     364     def _find_next_location(self, n_restarts):
#     365         def global_uncert(X):
# --> 366             return self._global_uncert_search(X, gp=deepcopy(self._gp))
#     367
#     368         best_x = None
#
# ~/Desktop/gpder/gpder/bayes/bayesian_opt_uncertainty.py in _global_uncert_search(self, X, gp)
#     421             dy = gp.predict_der(dX=X).reshape(-1, self._nparams)
#     422             dy_temp = np.concatenate((self.dtargets, dy))
# --> 423             gp.fit(X=X_temp, y=y_temp, dX=X_temp, dy=dy_temp)
#     424             uncert = np.trace(gp.kernel_(X=X_temp, dX=X_temp))
#     425         else:
#
# ~/Desktop/gpder/gpder/gaussian_process/gaussian_process.py in fit(self, X, y, dX, dy)
#     232                     theta_init = self._rng.uniform(bounds[:, 0], bounds[:, 1])
#     233                     optima.append(self._constrained_optimization(
# --> 234                         obj_func, theta_init, bounds))
#     235             # select the run which results in the minimal neg. log-marginal
#     236             # likelihood
#
# ~/Desktop/gpder/gpder/gaussian_process/gaussian_process.py in _constrained_optimization(self, obj_func, initial_theta, bounds)
#     630                 jac=True,
#     631                 #options={'maxiter':1000},
# --> 632                 bounds=bounds)
#     633                 _check_optimize_result("lbfgs", opt_res)
#     634             theta_opt, func_min = opt_res.x, opt_res.fun
#
# ~/.virtualenvs/python3_ml/lib/python3.6/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     608     elif meth == 'l-bfgs-b':
#     609         return _minimize_lbfgsb(fun, x0, args, jac, bounds,
# --> 610                                 callback=callback, **options)
#     611     elif meth == 'tnc':
#     612         return _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#
# ~/.virtualenvs/python3_ml/lib/python3.6/site-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, **unknown_options)
#     343             # until the completion of the current minimization iteration.
#     344             # Overwrite f and g:
# --> 345             f, g = func_and_grad(x)
#     346         elif task_str.startswith(b'NEW_X'):
#     347             # new iteration
#
# ~/.virtualenvs/python3_ml/lib/python3.6/site-packages/scipy/optimize/lbfgsb.py in func_and_grad(x)
#     293     else:
#     294         def func_and_grad(x):
# --> 295             f = fun(x, *args)
#     296             g = jac(x, *args)
#     297             return f, g
#
# ~/.virtualenvs/python3_ml/lib/python3.6/site-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     325     def function_wrapper(*wrapper_args):
#     326         ncalls[0] += 1
# --> 327         return function(*(wrapper_args + args))
#     328
#     329     return ncalls, function_wrapper
#
# ~/.virtualenvs/python3_ml/lib/python3.6/site-packages/scipy/optimize/optimize.py in __call__(self, x, *args)
#      63     def __call__(self, x, *args):
#      64         self.x = numpy.asarray(x).copy()
# ---> 65         fg = self.fun(x, *args)
#      66         self.jac = fg[1]
#      67         return fg[0]
#
# ~/Desktop/gpder/gpder/gaussian_process/gaussian_process.py in obj_func(theta, eval_gradient)
#     212                 if eval_gradient:
#     213                     lml, grad = self.log_marginal_likelihood(
# --> 214                         theta, eval_gradient=True, clone_kernel=False)
#     215                     return -lml, -grad
#     216                 else:
#
# ~/Desktop/gpder/gpder/gaussian_process/gaussian_process.py in log_marginal_likelihood(self, theta, eval_gradient, clone_kernel)
#     554             if self.has_derinfo_:
#     555                 K, K_gradient = kernel(self.X_train_, dX=self.dX_train_,
# --> 556                                        eval_gradient=True)
#     557             else:
#     558                 K, K_gradient = kernel(self.X_train_, eval_gradient=True)
#
# ~/Desktop/gpder/gpder/gaussian_process/kernels/deraware_kernel.py in __call__(self, X, dX, X_pred, eval_gradient)
#     185                              self._cov_wy(X=X_pred, dX=dX).T])
#     186
# --> 187         return self._kernel_hybrid(X, dX, eval_gradient=eval_gradient)
#     188
#     189     def _rbf(self, X, Y=None):
#
# ~/Desktop/gpder/gpder/gaussian_process/kernels/deraware_kernel.py in _kernel_hybrid(self, X, dX, eval_gradient)
#     331                        eval_gradient=False):
#     332         if eval_gradient:
# --> 333             Kww, Kww_grad = self._cov_ww(dX, eval_gradient=True)
#     334             Kwy, Kwy_grad = self._cov_wy(X, dX, eval_gradient=True)
#     335             Kyy, Kyy_grad = self._cov_yy(X, eval_gradient=True)
#
# ~/Desktop/gpder/gpder/gaussian_process/kernels/deraware_kernel.py in _cov_ww(self, dX, dY, eval_gradient)
#     250         K = np.zeros((ndX*ndim, ndY*ndim))
#     251         (K_grad_const, K_grad_lensc, K_grad_noise_X, K_grad_noise_dX) =\
# --> 252             self._initialize_gradients((ndX*ndim, ndY*ndim))
#     253         for i in range(ndim):
#     254             for j in range(ndim):
#
# ~/Desktop/gpder/gpder/gaussian_process/kernels/deraware_kernel.py in _initialize_gradients(self, kernel_dims)
#     377             K_grad_lensc = np.zeros((kernel_dims[0], kernel_dims[1], 1))
#     378         # -- wrt the log of the noise level of X -- #
# --> 379         if self.hyperparameter_noise_level_X.fixed:
#     380             K_grad_noise_X = np.empty((kernel_dims[0], kernel_dims[1], 0))
#     381         else:
#
# ~/Desktop/gpder/gpder/gaussian_process/kernels/deraware_kernel.py in hyperparameter_noise_level_X(self)
#     134     def hyperparameter_noise_level_X(self):
#     135         return Hyperparameter(
# --> 136             "noise_level_X", "numeric", self.noise_level_X_bounds)
#     137
#     138     @property
#
# ~/.virtualenvs/python3_ml/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py in __new__(cls, name, value_type, bounds, n_elements, fixed)
#     118     def __new__(cls, name, value_type, bounds, n_elements=1, fixed=None):
#     119         if not isinstance(bounds, str) or bounds != "fixed":
# --> 120             bounds = np.atleast_2d(bounds)
#     121             if n_elements > 1:  # vector-valued parameter
#     122                 if bounds.shape[0] == 1:
#
# <__array_function__ internals> in atleast_2d(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
bayes = UncertaintyOptimization(fun=Eff_MET50_sigmoid,
                                dfun=dEff_MET50_sigmoid,
                                ignore_convergence_warnings=True,
                                verbose=True,
                                param_bounds={'J_scale': (0.5, 1.5), 
                                              'j_scale': (0.5, 1.5)},
                                random_state=123)
bayes.minimize_uncertainty(params_train=X_train,
                           minimizer=minimizer,
                           gamma=0,
                           params_val=X_test,
                           niters=8,
                           minimizer_restarts=1,
                           gp_optimizer_restarts=10)

plot_gpr_evolution(bayes=copy.deepcopy(bayes), X_lower=0.5, X_upper=1.5)
plot_gpr_iterloss(bayes=copy.deepcopy(bayes))
# Out:
# | Iter | J_scale   | j_scale   | Target    | Uncert    | MSE val   | Uncert val|
# ================================================================================
# | 1    | 0.900000  | 1.000000  | 0.580745  | 51.072517 | 0.082897  | 13.804135 |
# | 2    | 1.000000  | 0.900000  | 0.787183  | 51.072517 | 0.082897  | 13.804135 |
# | 3    | 1.000000  | 1.000000  | 0.780826  | 51.072517 | 0.082897  | 13.804135 |
# | 4    | 1.000000  | 1.100000  | 0.661358  | 51.072517 | 0.082897  | 13.804135 |
# | 5    | 1.100000  | 1.000000  | 0.834261  | 51.072517 | 0.082897  | 13.804135 |
# | 6    | 0.536449  | 0.508398  | 0.162455  | 46.369454 | 0.073841  | 8.618147  |
# | 7    | 0.589052  | 1.493683  | 0.000000  | 39.650580 | 0.050453  | 4.963922  |
# | 8    | 1.534424  | 1.411390  | 0.942305  | 51.904104 | 0.029485  | 4.072317  |
# | 9    | 0.874686  | 0.756576  | 0.564237  | 61.005485 | 0.034451  | 3.890740  |
# | 10   | 1.526157  | 0.563401  | 0.000000  | 57.249280 | 0.028600  | 2.040075  |
# | 11   | 0.505161  | 1.166805  | 0.000000  | 56.191621 | 0.020622  | 1.572220  |
# | 12   | 0.829981  | 0.500000  | 0.180495  | 58.436132 | 0.015693  | 1.236887  |
# | 13   | 1.102287  | 1.472640  | 0.128046  | 59.995807 | 0.014084  | 0.773655  |
