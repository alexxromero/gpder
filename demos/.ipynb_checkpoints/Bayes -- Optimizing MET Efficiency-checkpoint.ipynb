# %%
import sys
sys.path.append("..")

import uproot 
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
import scipy.stats as st
import pandas as pd

from sklearn.metrics import mean_squared_error

# %%
f = uproot.open("./datasets/hist.root")
tree = f['tnt']

photon_pt = np.asarray(tree['a_pt'].array())
photon_eta = np.asarray(tree['a_eta'].array())
photon_phi = np.asarray(tree['a_phi'].array())

jet_pt = np.asarray(tree['j_pt'].array())
jet_eta = np.asarray(tree['j_eta'].array())
jet_phi = np.asarray(tree['j_phi'].array())

photon_threeM = []
jet_threeM = []

nevents = photon_pt.shape[0]
for i in range(nevents):
    if ((photon_pt[i] > 20) and (jet_pt[i] > 20)):
        photon_threeM.append([photon_pt[i], photon_eta[i], photon_phi[i]])
        jet_threeM.append([jet_pt[i], jet_eta[i], jet_phi[i]])
        
photon_threeM = np.asarray(photon_threeM)
jet_threeM = np.asarray(jet_threeM)

f.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/.pyenv/versions/3.7.6/lib/python3.7/site-packages/uproot/source/file.py in __init__(self, file_path, **options)
#     109         try:
# --> 110             self._file = numpy.memmap(self._file_path, dtype=self._dtype, mode="r")
#     111             self._fallback = None
#
# ~/.pyenv/versions/3.7.6/lib/python3.7/site-packages/numpy/core/memmap.py in __new__(subtype, filename, dtype, mode, offset, shape, order)
#     227         else:
# --> 228             f_ctx = open(os_fspath(filename), ('r' if mode == 'c' else mode)+'b')
#     229
#
# FileNotFoundError: [Errno 2] No such file or directory: './datasets/hist.root'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# ~/.pyenv/versions/3.7.6/lib/python3.7/site-packages/uproot/source/file.py in __init__(self, file_path)
#      36         try:
# ---> 37             self._file = open(self._file_path, "rb")
#      38         except uproot._util._FileNotFoundError:
#
# FileNotFoundError: [Errno 2] No such file or directory: './datasets/hist.root'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-526d43e7ea7a> in <module>
# ----> 1 f = uproot.open("./datasets/hist.root")
#       2 tree = f['tnt']
#       3
#       4 photon_pt = np.asarray(tree['a_pt'].array())
#       5 photon_eta = np.asarray(tree['a_eta'].array())
#
# ~/.pyenv/versions/3.7.6/lib/python3.7/site-packages/uproot/reading.py in open(path, object_cache, array_cache, custom_classes, decompression_executor, interpretation_executor, **options)
#     144         decompression_executor=decompression_executor,
#     145         interpretation_executor=interpretation_executor,
# --> 146         **options  # NOTE: a comma after **options breaks Python 2
#     147     )
#     148
#
# ~/.pyenv/versions/3.7.6/lib/python3.7/site-packages/uproot/reading.py in __init__(self, file_path, object_cache, array_cache, custom_classes, decompression_executor, interpretation_executor, **options)
#     552         )
#     553         self._source = Source(
# --> 554             file_path, **self._options  # NOTE: a comma after **options breaks Python 2
#     555         )
#     556
#
# ~/.pyenv/versions/3.7.6/lib/python3.7/site-packages/uproot/source/file.py in __init__(self, file_path, **options)
#     115             opts["num_workers"] = num_fallback_workers
#     116             self._fallback = uproot.source.file.MultithreadedFileSource(
# --> 117                 file_path, **opts  # NOTE: a comma after **opts breaks Python 2
#     118             )
#     119
#
# ~/.pyenv/versions/3.7.6/lib/python3.7/site-packages/uproot/source/file.py in __init__(self, file_path, **options)
#     244         self._file_path = file_path
#     245         self._executor = uproot.source.futures.ResourceThreadPoolExecutor(
# --> 246             [FileResource(file_path) for x in uproot._util.range(num_workers)]
#     247         )
#     248         self._num_bytes = os.path.getsize(self._file_path)
#
# ~/.pyenv/versions/3.7.6/lib/python3.7/site-packages/uproot/source/file.py in <listcomp>(.0)
#     244         self._file_path = file_path
#     245         self._executor = uproot.source.futures.ResourceThreadPoolExecutor(
# --> 246             [FileResource(file_path) for x in uproot._util.range(num_workers)]
#     247         )
#     248         self._num_bytes = os.path.getsize(self._file_path)
#
# ~/.pyenv/versions/3.7.6/lib/python3.7/site-packages/uproot/source/file.py in __init__(self, file_path)
#      37             self._file = open(self._file_path, "rb")
#      38         except uproot._util._FileNotFoundError:
# ---> 39             raise uproot._util._file_not_found(file_path)
#      40
#      41     @property
#
# FileNotFoundError: file not found
#
#     './datasets/hist.root'
#
# Files may be specified as:
#    * str/bytes: relative or absolute filesystem path or URL, without any colons
#          other than Windows drive letter or URL schema.
#          Examples: "rel/file.root", "C:\abs\file.root", "http://where/what.root"
#    * str/bytes: same with an object-within-ROOT path, separated by a colon.
#          Example: "rel/file.root:tdirectory/ttree"
#    * pathlib.Path: always interpreted as a filesystem path or URL only (no
#          object-within-ROOT path), regardless of whether there are any colons.
#          Examples: Path("rel:/file.root"), Path("/abs/path:stuff.root")
#
# Functions that accept many files (uproot.iterate, etc.) also allow:
#    * glob syntax in str/bytes and pathlib.Path.
#          Examples: Path("rel/*.root"), "/abs/*.root:tdirectory/ttree"
#    * dict: keys are filesystem paths, values are objects-within-ROOT paths.
#          Example: {"/data_v1/*.root": "ttree_v1", "/data_v2/*.root": "ttree_v2"}
#    * already-open TTree objects.
#    * iterables of the above.
